# %% [markdown]
# # Observe ModelSeries.records during training

# %%
import ModelSeries as ms
import util
from IPython.display import display, HTML

gt_df = util.DataExtractor().croppedData()
series = ms.ModelSeries(name = "runpod_oneshot_training2", gt_df = gt_df)

display(HTML(series.records.iloc[200:].to_html()))
# Out:
# Saving to: c:\Users\alexh\Desktop\cv4\obb_anns_hausarbeit\ds2_dense\ds2_dense\gt_space.json
# ModelSeries: loadJsonData()
# loadLatestCheckpoint available files: [100, 11, 12, 16, 21, 22, 35, 45, 9]
# loadLatestCheckpoint picked file: 100
# latest checkpoint: 100.pth
# [loadMode] Loaded weights from c:\Users\alexh\Desktop\cv4\obb_anns_hausarbeit\models\60@60@2@720\runpod_oneshot_training2\checkpoints\100.pth
# ...

# %%
print(series.eval_records.df[series.eval_records.df["class_id"] == 26])
# Out:
#        class_id            class_name  n_occurences  n_images  epoch  \
# 26           26  noteheadBlackInSpace        125410      1344      0
# 162          26  noteheadBlackInSpace        125410      1344      1
# 298          26  noteheadBlackInSpace        125410      1344      2
# 434          26  noteheadBlackInSpace        125410      1344      3
# 570          26  noteheadBlackInSpace        125410      1344      4
# ...         ...                   ...           ...       ...    ...
# 40010        26  noteheadBlackInSpace        125410      1344    275
# 40146        26  noteheadBlackInSpace        125410      1344    276
# 40282        26  noteheadBlackInSpace        125410      1344    277
# 40418        26  noteheadBlackInSpace        125410      1344    278
# 40554        26  noteheadBlackInSpace        125410      1344    279
#
#             mAP      mREC
# 26     0.000000  0.000000
# 162    0.004863  0.017767
# 298    0.019795  0.019491
# 434    0.024871  0.023601
# ...
